# %%
import os
import re
import pandas as pd

# Folders for input/output
results_folder = r"E:\forecastingfolder\finalresultspl"
csv_folder = r"E:\chaosgrandfinale\teams1_updated"
chaotic_folder = r"E:\forecasting1\forecastingfolder1\chaotic_columns"
stochastic_folder = r"E:\forecasting1\forecastingfolder1\stochastic columns"

# Ensure output folders exist (though subfolders for each team will be created as needed)
os.makedirs(chaotic_folder, exist_ok=True)
os.makedirs(stochastic_folder, exist_ok=True)

# Regex to capture:
# 1) Team name from the line "Chaos Classification Results for <TEAMNAME>"
# 2) Columns and their classification from lines like:
#       Column: FTHG
#       Classification: stochastic
team_name_pattern = re.compile(r"Chaos Classification Results for\s+(.+)")
column_class_pattern = re.compile(
    r"Column:\s+(.+?)\s+Classification:\s+(chaotic|stochastic)",
    re.IGNORECASE | re.DOTALL
)

# Iterate over each text file in the results folder
for file_name in os.listdir(results_folder):
    if file_name.lower().endswith(".txt"):
        file_path = os.path.join(results_folder, file_name)
        
        # Read the entire text file
        with open(file_path, "r", encoding="utf-8") as f:
            content = f.read()
        
        # Extract team name
        match_team = team_name_pattern.search(content)
        if not match_team:
            # If we can't find a team name, skip this file
            print(f"Team name not found in {file_name}. Skipping.")
            continue
        
        team_name = match_team.group(1).strip()
        
        # Load the CSV for this team from pldenoisedwavecsv
        # e.g. "Arsenal_denoised.csv", "Everton_denoised.csv", etc.
        csv_file_path = os.path.join(csv_folder, f"{team_name}.csv")
        if not os.path.exists(csv_file_path):
            print(f"CSV file for team '{team_name}' not found at {csv_file_path}. Skipping.")
            continue
        
        df = pd.read_csv(csv_file_path)
        
        # Find all (column_name, classification) pairs
        matches = column_class_pattern.findall(content)
        
        for col_name, classification in matches:
            col_name = col_name.strip()
            classification = classification.lower().strip()  # "chaotic" or "stochastic"
            
            # Skip columns that do not exist in the CSV
            if col_name not in df.columns:
                print(f"Column '{col_name}' not found in CSV for team '{team_name}'. Skipping.")
                continue
            
            # Retrieve the column data
            col_data = df[col_name]
            
            # Determine the output folder based on classification
            if classification == "chaotic":
                out_dir = os.path.join(chaotic_folder, team_name)
            else:  # stochastic
                out_dir = os.path.join(stochastic_folder, team_name)
            
            # Create the team-specific subfolder if needed
            os.makedirs(out_dir, exist_ok=True)
            
            # Build the output path: <out_dir>/<column_name>.txt
            out_path = os.path.join(out_dir, f"{col_name}.txt")
            
            # Write the column values to a text file (one value per line)
            col_data.to_csv(out_path, index=False, header=False)
            
            print(f"Wrote column '{col_name}' ({classification}) for team '{team_name}' to {out_path}.")
# Out:
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Arsenal'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\HTP.txt.
# Wrote column 'ATP' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\ATP.txt.
# Wrote column 'MW' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\MW.txt.
# Wrote column 'HTFormPts' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\HTFormPts.txt.
# Wrote column 'ATFormPts' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\HTWinStreak3.txt.
# Wrote column 'HTWinStreak5' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\HTWinStreak5.txt.
# Wrote column 'HTLossStreak3' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\HTLossStreak3.txt.
# Wrote column 'HTLossStreak5' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\HTLossStreak5.txt.
# Wrote column 'ATWinStreak3' (chaotic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\chaotic_columns\Arsenal\ATWinStreak3.txt.
# Wrote column 'ATWinStreak5' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\ATWinStreak5.txt.
# Wrote column 'ATLossStreak3' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\ATLossStreak3.txt.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Arsenal' to E:\forecasting1\forecastingfolder1\stochastic columns\Arsenal\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Aston Villa'. Skipping.
# Wrote column 'FTAG' (chaotic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\chaotic_columns\Aston Villa\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\chaotic_columns\Aston Villa\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\chaotic_columns\Aston Villa\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\chaotic_columns\Aston Villa\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\chaotic_columns\Aston Villa\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\HTP.txt.
# Wrote column 'ATP' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\ATP.txt.
# Wrote column 'MW' (chaotic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\chaotic_columns\Aston Villa\MW.txt.
# Wrote column 'HTFormPts' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\HTFormPts.txt.
# Wrote column 'ATFormPts' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\HTWinStreak3.txt.
# Wrote column 'HTWinStreak5' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\HTWinStreak5.txt.
# Wrote column 'HTLossStreak3' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\HTLossStreak3.txt.
# Wrote column 'HTLossStreak5' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\HTLossStreak5.txt.
# Wrote column 'ATWinStreak3' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\ATWinStreak3.txt.
# Wrote column 'ATWinStreak5' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\ATWinStreak5.txt.
# Wrote column 'ATLossStreak3' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\ATLossStreak3.txt.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Aston Villa' to E:\forecasting1\forecastingfolder1\stochastic columns\Aston Villa\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Birmingham'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Birmingham\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Birmingham\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Birmingham\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Birmingham\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\HTP.txt.
# Wrote column 'ATP' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\ATP.txt.
# Column 'MW
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: HTFormPts' not found in CSV for team 'Birmingham'. Skipping.
# Wrote column 'ATFormPts' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\HTWinStreak3.txt.
# Wrote column 'HTWinStreak5' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\HTWinStreak5.txt.
# Wrote column 'HTLossStreak3' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\HTLossStreak3.txt.
# Column 'HTLossStreak5
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: ATWinStreak3' not found in CSV for team 'Birmingham'. Skipping.
# Wrote column 'ATWinStreak5' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\ATWinStreak5.txt.
# Wrote column 'ATLossStreak3' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\ATLossStreak3.txt.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Birmingham' to E:\forecasting1\forecastingfolder1\stochastic columns\Birmingham\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Blackburn'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\chaotic_columns\Blackburn\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\chaotic_columns\Blackburn\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\chaotic_columns\Blackburn\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\chaotic_columns\Blackburn\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\HTP.txt.
# Wrote column 'ATP' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\ATP.txt.
# Wrote column 'MW' (chaotic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\chaotic_columns\Blackburn\MW.txt.
# Wrote column 'HTFormPts' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\HTFormPts.txt.
# Wrote column 'ATFormPts' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\HTWinStreak3.txt.
# Wrote column 'HTWinStreak5' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\HTWinStreak5.txt.
# Wrote column 'HTLossStreak3' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\HTLossStreak3.txt.
# Wrote column 'HTLossStreak5' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\HTLossStreak5.txt.
# Wrote column 'ATWinStreak3' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\ATWinStreak3.txt.
# Wrote column 'ATWinStreak5' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\ATWinStreak5.txt.
# Wrote column 'ATLossStreak3' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\ATLossStreak3.txt.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Blackburn' to E:\forecasting1\forecastingfolder1\stochastic columns\Blackburn\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Bolton'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Bolton\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Bolton\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Bolton\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Bolton\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\HTP.txt.
# Wrote column 'ATP' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\ATP.txt.
# Wrote column 'MW' (chaotic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Bolton\MW.txt.
# Wrote column 'HTFormPts' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\HTFormPts.txt.
# Wrote column 'ATFormPts' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\HTWinStreak3.txt.
# Wrote column 'HTWinStreak5' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\HTWinStreak5.txt.
# Wrote column 'HTLossStreak3' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\HTLossStreak3.txt.
# Wrote column 'HTLossStreak5' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\HTLossStreak5.txt.
# Wrote column 'ATWinStreak3' (chaotic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Bolton\ATWinStreak3.txt.
# Wrote column 'ATWinStreak5' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\ATWinStreak5.txt.
# Wrote column 'ATLossStreak3' (chaotic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Bolton\ATLossStreak3.txt.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Bolton' to E:\forecasting1\forecastingfolder1\stochastic columns\Bolton\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Everton'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Everton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Everton\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Everton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Everton\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Everton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Everton\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Everton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Everton\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\HTP.txt.
# Wrote column 'ATP' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\ATP.txt.
# Wrote column 'MW' (chaotic) for team 'Everton' to E:\forecasting1\forecastingfolder1\chaotic_columns\Everton\MW.txt.
# Wrote column 'HTFormPts' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\HTFormPts.txt.
# Wrote column 'ATFormPts' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\HTWinStreak3.txt.
# Wrote column 'HTWinStreak5' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\HTWinStreak5.txt.
# Wrote column 'HTLossStreak3' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\HTLossStreak3.txt.
# Wrote column 'HTLossStreak5' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\HTLossStreak5.txt.
# Wrote column 'ATWinStreak3' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\ATWinStreak3.txt.
# Wrote column 'ATWinStreak5' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\ATWinStreak5.txt.
# Wrote column 'ATLossStreak3' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\ATLossStreak3.txt.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Everton' to E:\forecasting1\forecastingfolder1\stochastic columns\Everton\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Fulham'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Fulham\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Fulham\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Fulham\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Fulham\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\HTP.txt.
# Wrote column 'ATP' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\ATP.txt.
# Wrote column 'MW' (chaotic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Fulham\MW.txt.
# Wrote column 'HTFormPts' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\HTFormPts.txt.
# Wrote column 'ATFormPts' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\HTWinStreak3.txt.
# Wrote column 'HTWinStreak5' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\HTWinStreak5.txt.
# Wrote column 'HTLossStreak3' (chaotic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\chaotic_columns\Fulham\HTLossStreak3.txt.
# Wrote column 'HTLossStreak5' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\HTLossStreak5.txt.
# Wrote column 'ATWinStreak3' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\ATWinStreak3.txt.
# Wrote column 'ATWinStreak5' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\ATWinStreak5.txt.
# Wrote column 'ATLossStreak3' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\ATLossStreak3.txt.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Fulham' to E:\forecasting1\forecastingfolder1\stochastic columns\Fulham\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Hull'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\FTAG.txt.
# Wrote column 'HTGS' (chaotic) for team 'Hull' to E:\forecasting1\forecastingfolder1\chaotic_columns\Hull\HTGS.txt.
# Wrote column 'ATGS' (chaotic) for team 'Hull' to E:\forecasting1\forecastingfolder1\chaotic_columns\Hull\ATGS.txt.
# Wrote column 'HTGC' (chaotic) for team 'Hull' to E:\forecasting1\forecastingfolder1\chaotic_columns\Hull\HTGC.txt.
# Wrote column 'ATGC' (chaotic) for team 'Hull' to E:\forecasting1\forecastingfolder1\chaotic_columns\Hull\ATGC.txt.
# Wrote column 'HTP' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\HTP.txt.
# Wrote column 'ATP' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\ATP.txt.
# Column 'MW
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: HTFormPts' not found in CSV for team 'Hull'. Skipping.
# Wrote column 'ATFormPts' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\ATFormPts.txt.
# Wrote column 'HTWinStreak3' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\HTWinStreak3.txt.
# Column 'HTWinStreak5
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: HTLossStreak3' not found in CSV for team 'Hull'. Skipping.
# Wrote column 'HTLossStreak5' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\HTLossStreak5.txt.
# Wrote column 'ATWinStreak3' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\ATWinStreak3.txt.
# Column 'ATWinStreak5
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: ATLossStreak3' not found in CSV for team 'Hull'. Skipping.
# Wrote column 'ATLossStreak5' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\ATLossStreak5.txt.
# Wrote column 'HTGD' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\HTGD.txt.
# Wrote column 'ATGD' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\ATGD.txt.
# Wrote column 'DiffPts' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\DiffPts.txt.
# Wrote column 'DiffFormPts' (stochastic) for team 'Hull' to E:\forecasting1\forecastingfolder1\stochastic columns\Hull\DiffFormPts.txt.
# Column 'Year NOT FOUND in the dataset.
# --------------------------------------------------------------
# Column: FTHG' not found in CSV for team 'Ipswich'. Skipping.
# Wrote column 'FTAG' (stochastic) for team 'Ipswich' to E:\forecasting1\forecastingfolder1\stochastic columns\Ipswich\FTAG.txt.
# Column 'HTGS
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: ATGS
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: HTGC
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: ATGC
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: HTP
#   Classification: nonstationary
#   K-statistic:
#   Permutation Entropy:
# --------------------------------------------------------------
# Column: ATP' not found in CSV for team 'Ipswich'. Skipping.
